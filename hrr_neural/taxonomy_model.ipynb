# %% [markdown]
# This model learns the odd-even program. Since it was difficult to set a threshold, a winner take all is used for cleanup in the associative memories.

# %%
import nengo
import nengo_gui
import nengo.spa as spa
from nengo.spa import Vocabulary
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [raw]
# Taxonomy encoded:
#
#             [0]
#            /   \
#          /       \
#        [1]        [6]
#       /   \       /  \
#     [2]   [7]   [12] [13]
#     /     /  \
#   [3]    [8] [9]
#    /     /     \
#  [4]    [10]  [11]
#   /
# [5]

# %%
dim = 64*2*2*2
rng = np.random.RandomState(12)
vocab = Vocabulary(dimensions=dim, rng=rng, max_similarity=0.02, unitary=True)

incr = vocab.parse("INCREMENT")
zero = vocab.parse("ZERO")

vocab.add("ONE", vocab.parse("ZERO*INCREMENT+B"))
vocab.add("SIX", vocab.parse("ZERO*INCREMENT+G"))

vocab.add("TWO", vocab.parse("ONE*INCREMENT+C"))
vocab.add("SEVEN", vocab.parse("ONE*INCREMENT+H"))

vocab.add("THREE", vocab.parse("TWO*INCREMENT+D"))
vocab.add("FOUR", vocab.parse("THREE*INCREMENT+E"))
vocab.add("FIVE", vocab.parse("FOUR*INCREMENT+F"))

vocab.add("EIGHT", vocab.parse("SEVEN*INCREMENT+I"))
vocab.add("TEN", vocab.parse("EIGHT*INCREMENT+K"))

vocab.add("NINE", vocab.parse("SEVEN*INCREMENT+J"))
vocab.add("ELEVEN", vocab.parse("NINE*INCREMENT+L"))

vocab.add("TWELVE", vocab.parse("SIX*INCREMENT+M"))
vocab.add("THIRTEEN", vocab.parse("SIX*INCREMENT+N"))

# create sub vocabs
num_vocab = vocab.create_subset(['ZERO', 'ONE', 'TWO', 'THREE', 'FOUR', 'FIVE', 'SIX', 
                               'SEVEN', 'EIGHT', 'NINE', 'TEN', 'ELEVEN', 'TWELVE', 'THIRTEEN'])
# Out:
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=512, M=14)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=512, M=16)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=512, M=18)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=512, M=20)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=512, M=22)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=512, M=24)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=512, M=26)
#   len(self.pointers)))

# %%
model = spa.SPA() 
with model:
    model.a = spa.State(dim, vocab=vocab)
    model.b = spa.State(dim, vocab=vocab)
    model.trans = spa.State(dim, vocab=vocab, feedback=1)
    
    model.cue = spa.State(dim, vocab=vocab)
    model.succ = spa.State(dim, vocab=vocab)
    model.pred = spa.State(dim, vocab=vocab)
    model.assoc_memSucc = spa.AssociativeMemory(input_vocab=num_vocab, threshold=0.6, threshold_output=True)
    model.assoc_memPred = spa.AssociativeMemory(input_vocab=num_vocab, wta_output=True, threshold_output=True)
    #model.parity = spa.State(dim, vocab=vocab)
    
    actions = spa.Actions(
        'trans = ~a * b',
        'succ = trans*cue',
        'pred = ~trans*cue',
        'assoc_memSucc = succ',
        'assoc_memPred = pred',
        #'parity = ~PARITY*assoc_memSucc',
    )

    model.cortical = spa.Cortical(actions)
    
    #par_probe = nengo.Probe(model.parity.output, synapse=0.03)
    cue_probe = nengo.Probe(model.cue.output, synapse=0.03)
    
    succ_probe = nengo.Probe(model.succ.output, synapse=0.03)
    pred_probe = nengo.Probe(model.pred.output, synapse=0.03)
    
    amsucc_inprobe = nengo.Probe(model.assoc_memSucc.input)
    amsucc_outprobe = nengo.Probe(model.assoc_memSucc.output, synapse=0.03)
    
    ampred_inprobe = nengo.Probe(model.assoc_memPred.input)
    ampred_outprobe = nengo.Probe(model.assoc_memPred.output, synapse=0.03)

# %%
def inp1(t):
    if t <= 0.2:
        return 'ZERO'                               
    elif (0.2 < t<=0.4):      
        return 'ONE'
    elif (0.4 < t<=0.6):      
        return 'ONE' 
    elif (0.6 < t<=0.8):      
        return 'TWO'
    elif (0.8 < t<=1.0):      
        return 'SEVEN'
    else:
        return '0'
 
            
def inp2(t):
    if t <= 0.2:
        return 'ONE'                                
    elif (0.2 < t<=0.4):      
        return 'TWO'
    elif (0.4 < t<=0.6):      
        return 'SEVEN'
    elif (0.6 < t<=0.8):      
        return 'THREE'
    elif (0.8 < t<=1.0):      
        return 'EIGHT'
    else:
        return '0'
 
    
def cue_inp(t):
    if 1.0 < t <= 1.2:
        return 'SIX'
    else:
        return '0'

    
    
with model:
    model.input = spa.Input(a=inp1, b=inp2, cue=cue_inp)     # provide sensory input which determines cortex state

# %%
# normalize=True to compute cosine similarity
def plot_similarities(input_data,
                      output_data,
                      vocab1,
                      vocab2=None,
                      autoscale=False):
    if vocab2 is None:
        vocab2 = vocab1

    ymin, ymax = -1.2, 1.2
    plt.figure(figsize=(12, 8))
    plt.subplot(1, 2, 1)
    plt.ylim(ymin, ymax)
    if autoscale:
        plt.autoscale(autoscale, axis='y')
    plt.grid(True)
    plt.plot(t, spa.similarity(input_data, vocab1, normalize=True))
    plt.title("Input similarity")
    plt.xlabel("Time")
    plt.xlim(right=t[-1])
    plt.legend(
        vocab1.keys, loc='upper center', bbox_to_anchor=(0.5, -0.13), ncol=3)

    plt.subplot(1, 2, 2)
    plt.plot(t, spa.similarity(output_data, vocab2, normalize=True))
    plt.title("Output similarity")
    plt.xlabel("Time")
    plt.xlim(right=t[-1])
    plt.ylim(ymin, ymax)
    if autoscale:
        plt.autoscale(autoscale, axis='y')
    plt.grid(True)
    plt.legend(
        vocab2.keys, loc='upper center', bbox_to_anchor=(0.5, -0.13), ncol=3)
    plt.tight_layout()

# %%
sim = nengo.Simulator(model)
sim.run(1.5)
t = sim.trange()
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.

# %%
# Cue
plt.figure()
plt.plot(sim.trange(), spa.similarity(sim.data[cue_probe], num_vocab, normalize=True))
plt.xlabel("Time [s]")
plt.ylabel("Output similarity")
plt.title("Cue")
plt.legend(num_vocab.keys, loc='best', bbox_to_anchor=(1.05, 1), borderaxespad=0.0);


# Successor
plt.figure()
plt.plot(sim.trange(), spa.similarity(sim.data[succ_probe], num_vocab))
plt.xlabel("Time [s]")
plt.ylabel("Output similarity")
plt.title("Successor")
plt.legend(num_vocab.keys, loc='best', bbox_to_anchor=(1.05, 1), borderaxespad=0.0);

plot_similarities(sim.data[amsucc_inprobe], sim.data[amsucc_outprobe], num_vocab)

# Predecessor
plt.figure()
plt.plot(sim.trange(), spa.similarity(sim.data[pred_probe], num_vocab))
plt.xlabel("Time [s]")
plt.ylabel("Output similarity")
plt.title("Predecessor")
plt.legend(num_vocab.keys, loc='best', bbox_to_anchor=(1.05, 1), borderaxespad=0.0);

plot_similarities(sim.data[ampred_inprobe], sim.data[ampred_outprobe], num_vocab)

# # Parity
# plt.figure()
# plt.plot(sim.trange(), spa.similarity(sim.data[par_probe], par_vocab))
# plt.xlabel("Time [s]")
# plt.ylabel("Output similarity")
# plt.title("Parity")
# plt.legend(par_vocab.keys, loc='best', bbox_to_anchor=(1.05, 1), borderaxespad=0.0);

# %%
from nengo_gui.ipython import IPythonViz
IPythonViz(model)
# Out:
#             <script type="text/javascript" id="3d621dfc-2a3c-4d3f-920d-4b5b1d5d2b20">
#             {
#                 let req = new XMLHttpRequest();
#                 req.addEventListener("load", function() {
#                     if (this.status != 200 && this.response != 'OK') {
#                         let p = document.getElementById('3d621dfc-2a3c-4d3f-920d-4b5b1d5d2b20').parentNode;
#                         p.innerHTML +=
#                             'The nengo_gui.jupyter notebook server ' +
#                             'extension was not loaded. Please activate it ' +
#                             'with the following command:' +
#                             '<pre>jupyter serverextension enable ' +
#                             'nengo_gui.jupyter</pre>';
#                         p.classList.add('output_stderr');
#                     }
#                 });
#                 req.open('GET', './nengo/check', true);
#                 req.send();
#             }
#             </script>
#                 <div id="a9d6ec9a-703b-42e2-9d5a-257364cb3a68">
#                     <iframe
#                         src="./nengo/49262/?token=46ca764215ae98411981a03d77d7b3b6b3dc60f1edc1e565"
#                         width="100%"
#                         height="600"
#                         frameborder="0"
#                         class="cell"
#                         style="border: 1px solid #eee; box-sizing: border-box;"
#                         allowfullscreen></iframe>
#                 </div>
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=512, M=28)
#   len(self.pointers)))

# %%
model.n_neurons
# Out:
# 202800
