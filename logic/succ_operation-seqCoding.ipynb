# %% [markdown]
# Trying out the sequence construction without gender

# %%
import nengo
import nengo.spa as spa
from nengo.spa import Vocabulary
import numpy as np

# %%
rng = np.random.RandomState(12)
dim = 64*2

vocab = Vocabulary(dimensions=dim, rng=rng, max_similarity=0.02, unitary=True)
#zero = spa.SemanticPointer(dim)

incr = vocab.parse("INCREMENT")


zero = vocab.parse("ZERO")
vocab.add("ONE", vocab.parse("ZERO*INCREMENT+B"))
vocab.add("TWO", vocab.parse("ONE*INCREMENT+C"))
vocab.add("THREE", vocab.parse("TWO*INCREMENT+D"))
vocab.add("FOUR", vocab.parse("THREE*INCREMENT+E"))
vocab.add("FIVE", vocab.parse("FOUR*INCREMENT+F"))
vocab.add("SIX", vocab.parse("FIVE*INCREMENT+G"))
vocab.add("SEVEN", vocab.parse("SIX*INCREMENT+H"))
vocab.add("EIGHT", vocab.parse("SEVEN*INCREMENT+I"))
vocab.add("NINE", vocab.parse("EIGHT*INCREMENT+J"))
vocab.add("TEN", vocab.parse("NINE*INCREMENT+K"))
vocab.add("ELEVEN", vocab.parse("TEN*INCREMENT+L"))
vocab.add("TWELVE", vocab.parse("ELEVEN*INCREMENT+M"))


one = vocab.parse("ONE")
two = vocab.parse("TWO")
three = vocab.parse("THREE")
four = vocab.parse("FOUR")
five = vocab.parse("FIVE")
six = vocab.parse("SIX")
seven = vocab.parse("SEVEN")
eight = vocab.parse("EIGHT")
nine = vocab.parse("EIGHT*INCREMENT")
ten = vocab.parse("NINE*INCREMENT")

#nine = vocab.parse("NUMBER*NINE+PARITY*EVEN")
#ten = vocab.parse("NUMBER*TEN+PARITY*EVEN")
# Out:
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=128, M=10)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=128, M=14)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=128, M=16)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=128, M=18)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=128, M=20)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=128, M=22)
#   len(self.pointers)))
# /Users/sugandha/nengo/nengo/spa/vocab.py:114: UserWarning: Could not create a semantic pointer with max_similarity=0.02 (D=128, M=24)
#   len(self.pointers)))

# %%
# Compute the transformation and convert it into a SP object
T = (~zero*one + ~one*two + ~two*three + ~three*four + ~four*five).v/5 # + ~five*six + ~six*seven + ~seven*eight).v / 8
T = spa.SemanticPointer(T)
print (type(T))

# As expected, the transformation vector is very similar to the increment vector
#print (T.v)
#print (incr.v)
print (np.dot(incr.v, T.v))   # dot product ~ 1
# Out:
# <class 'nengo.spa.pointer.SemanticPointer'>
# 2.7402320066949555

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


test = (eight * T*T*T*T).v

similarity = []
for sp_name in vocab.keys:
    vec = vocab.parse(sp_name)
    similarity.append(vec.compare(test))
 
   
#similarity = vocab.compare(test)    # compute dot product with each vector in the vocab
  
plt.figure(figsize = (10,10))    
plt.plot(vocab.keys, similarity, 'o', label=vocab.keys)   
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)

# %% [markdown]
# Succ1, succ2, succ3 all work here.

# %% [markdown]
# The other direct encoding of sequences is obviously less complex and more efficient (requires less dimensions)
